# %% [markdown]
# # Doppler shift calculations

# %%
from astropy.constants import c
import numpy as np
import scipy
import skyfield
import h5py

#i just put random values
f_tx = 230e6 #Hz frequency of transmitter
wvl_tx = c.value / f_tx #m, wavelength of transmitter

v_bistatic = -fD * wvl_tx
